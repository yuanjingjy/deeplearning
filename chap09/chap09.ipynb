# %% [markdown]
# #### 过拟合问题实战
# #### 基于月牙形状的2分类数据集的过拟合与欠拟合模型进行完整的实战。

# %%
#导入数据生成工具
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# 导入数据集生成工具
import numpy as np
import seaborn as sns
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, Sequential, regularizers
from mpl_toolkits.mplot3d import Axes3D

plt.rcParams['font.size'] = 16
plt.rcParams['font.family'] = ['STKaiti']
plt.rcParams['axes.unicode_minus'] = False

# OUTPUT_DIR = 'output_dir'
N_EPOCHS = 500


def load_dataset():
    # 采样点数
    N_SAMPLES = 1000
    # 测试数量比率
    TEST_SIZE = None

    # 从 moon 分布中随机采样 1000 个点，并切分为训练集-测试集
    X, y = make_moons(n_samples=N_SAMPLES, noise=0.25, random_state=100)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=42)
    return X, y, X_train, X_test, y_train, y_test


def make_plot(X, y, plot_name, file_name, XX=None, YY=None, preds=None, dark=False, output_dir=OUTPUT_DIR):
    # 绘制数据集的分布， X 为 2D 坐标， y 为数据点的标签
    if dark:
        plt.style.use('dark_background')
    else:
        sns.set_style("whitegrid")
    axes = plt.gca()
    axes.set_xlim([-2, 3])
    axes.set_ylim([-1.5, 2])
    axes.set(xlabel="$x_1$", ylabel="$x_2$")
    plt.title(plot_name, fontsize=20, fontproperties='SimHei')
    plt.subplots_adjust(left=0.20)
    plt.subplots_adjust(right=0.80)
    if XX is not None and YY is not None and preds is not None:
        plt.contourf(XX, YY, preds.reshape(XX.shape), 25, alpha=0.08, cmap=plt.cm.Spectral)
        plt.contour(XX, YY, preds.reshape(XX.shape), levels=[.5], cmap="Greys", vmin=0, vmax=.6)
    # 绘制散点图，根据标签区分颜色m=markers
    markers = ['o' if i == 1 else 's' for i in y.ravel()]
    mscatter(X[:, 0], X[:, 1], c=y.ravel(), s=20, cmap=plt.cm.Spectral, edgecolors='none', m=markers, ax=axes)
    # 保存矢量图
#     plt.savefig( file_name)
#     plt.close()
    plt.show()


def mscatter(x, y, ax=None, m=None, **kw):
    import matplotlib.markers as mmarkers
    if not ax: ax = plt.gca()
    sc = ax.scatter(x, y, **kw)
    if (m is not None) and (len(m) == len(x)):
        paths = []
        for marker in m:
            if isinstance(marker, mmarkers.MarkerStyle):
                marker_obj = marker
            else:
                marker_obj = mmarkers.MarkerStyle(marker)
            path = marker_obj.get_path().transformed(
                marker_obj.get_transform())
            paths.append(path)
        sc.set_paths(paths)
    return sc


def network_layers_influence(X_train, y_train):
    # 构建 5 种不同层数的网络
    for n in range(5):
        # 创建容器
        model = Sequential()
        # 创建第一层
        model.add(layers.Dense(8, input_dim=2, activation='relu'))
        # 添加 n 层，共 n+2 层
        for _ in range(n):
            model.add(layers.Dense(32, activation='relu'))
        # 创建最末层
        model.add(layers.Dense(1, activation='sigmoid'))
        # 模型装配与训练
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        model.fit(X_train, y_train, epochs=N_EPOCHS, verbose=1)
        # 绘制不同层数的网络决策边界曲线
        # 可视化的 x 坐标范围为[-2, 3]
        xx = np.arange(-2, 3, 0.01)
        # 可视化的 y 坐标范围为[-1.5, 2]
        yy = np.arange(-1.5, 2, 0.01)
        # 生成 x-y 平面采样网格点，方便可视化
        XX, YY = np.meshgrid(xx, yy)
        preds = model.predict_classes(np.c_[XX.ravel(), YY.ravel()])
        title = "网络层数：{0}".format(2 + n)
        file = "网络容量_%i.png" % (2 + n)
        make_plot(X_train, y_train, title, file, XX, YY, preds, output_dir=OUTPUT_DIR + '/network_layers')


def dropout_influence(X_train, y_train):
    # 构建 5 种不同数量 Dropout 层的网络
    for n in range(5):
        # 创建容器
        model = Sequential()
        # 创建第一层
        model.add(layers.Dense(8, input_dim=2, activation='relu'))
        counter = 0
        # 网络层数固定为 5
        for _ in range(5):
            model.add(layers.Dense(64, activation='relu'))
        # 添加 n 个 Dropout 层
        if counter < n:
            counter += 1
            model.add(layers.Dropout(rate=0.5))

        # 输出层
        model.add(layers.Dense(1, activation='sigmoid'))
        # 模型装配
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        # 训练
        model.fit(X_train, y_train, epochs=N_EPOCHS, verbose=1)
        # 绘制不同 Dropout 层数的决策边界曲线
        # 可视化的 x 坐标范围为[-2, 3]
        xx = np.arange(-2, 3, 0.01)
        # 可视化的 y 坐标范围为[-1.5, 2]
        yy = np.arange(-1.5, 2, 0.01)
        # 生成 x-y 平面采样网格点，方便可视化
        XX, YY = np.meshgrid(xx, yy)
        preds = model.predict_classes(np.c_[XX.ravel(), YY.ravel()])
        title = "无Dropout层" if n == 0 else "{0}层 Dropout层".format(n)
        file = "Dropout_%i.png" % n
        make_plot(X_train, y_train, title, file, XX, YY, preds, output_dir=OUTPUT_DIR + '/dropout')


def build_model_with_regularization(_lambda):
    # 创建带正则化项的神经网络
    model = Sequential()
    model.add(layers.Dense(8, input_dim=2, activation='relu'))  # 不带正则化项
    # 2-4层均是带 L2 正则化项
    model.add(layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(_lambda)))
    model.add(layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(_lambda)))
    model.add(layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(_lambda)))
    # 输出层
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])  # 模型装配
    return model


def plot_weights_matrix(model, layer_index, plot_name, file_name, output_dir=OUTPUT_DIR):
    # 绘制权值范围函数
    # 提取指定层的权值矩阵
    weights = model.layers[layer_index].get_weights()[0]
    shape = weights.shape
    # 生成和权值矩阵等大小的网格坐标
    X = np.array(range(shape[1]))
    Y = np.array(range(shape[0]))
    X, Y = np.meshgrid(X, Y)
    # 绘制3D图
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    plt.title(plot_name, fontsize=20, fontproperties='SimHei')
    # 绘制权值矩阵范围
    ax.plot_surface(X, Y, weights, cmap=plt.get_cmap('rainbow'), linewidth=0)
    # 设置坐标轴名
    ax.set_xlabel('网格x坐标', fontsize=16, rotation=0, fontproperties='SimHei')
    ax.set_ylabel('网格y坐标', fontsize=16, rotation=0, fontproperties='SimHei')
    ax.set_zlabel('权值', fontsize=16, rotation=90, fontproperties='SimHei')
    # 保存矩阵范围图
    plt.savefig(output_dir + "/" + file_name + ".svg")
    plt.close(fig)


def regularizers_influence(X_train, y_train):
    for _lambda in [1e-5, 1e-3, 1e-1, 0.12, 0.13]:  # 设置不同的正则化系数
        # 创建带正则化项的模型
        model = build_model_with_regularization(_lambda)
        # 模型训练
        model.fit(X_train, y_train, epochs=N_EPOCHS, verbose=1)
        # 绘制权值范围
        layer_index = 2
        plot_title = "正则化系数：{}".format(_lambda)
        file_name = "正则化网络权值_" + str(_lambda)
        # 绘制网络权值范围图
        plot_weights_matrix(model, layer_index, plot_title, file_name, output_dir=OUTPUT_DIR + '/regularizers')
        # 绘制不同正则化系数的决策边界线
        # 可视化的 x 坐标范围为[-2, 3]
        xx = np.arange(-2, 3, 0.01)
        # 可视化的 y 坐标范围为[-1.5, 2]
        yy = np.arange(-1.5, 2, 0.01)
        # 生成 x-y 平面采样网格点，方便可视化
        XX, YY = np.meshgrid(xx, yy)
        preds = model.predict_classes(np.c_[XX.ravel(), YY.ravel()])
        title = "正则化系数：{}".format(_lambda)
        file = "正则化_%g.svg" % _lambda
        make_plot(X_train, y_train, title, file, XX, YY, preds, output_dir=OUTPUT_DIR + '/regularizers')


def main():
    X, y, X_train, X_test, y_train, y_test = load_dataset()
    # 绘制数据集分布
    make_plot(X, y, None, "月牙形状二分类数据集分布.svg")
    # 网络层数的影响
    network_layers_influence(X_train, y_train)
    # Dropout的影响
    dropout_influence(X_train, y_train)
    # 正则化的影响
    regularizers_influence(X_train, y_train)


if __name__ == '__main__':
    main()
# Out:
# Train on 750 samples
# Epoch 1/500
# 750/750 [==============================] - 1s 2ms/sample - loss: 0.6123 - accuracy: 0.7453
# Epoch 2/500
# 750/750 [==============================] - 0s 45us/sample - loss: 0.5888 - accuracy: 0.8133
# Epoch 3/500
# 750/750 [==============================] - 0s 45us/sample - loss: 0.5678 - accuracy: 0.8347
# Epoch 4/500
# 750/750 [==============================] - 0s 44us/sample - loss: 0.5470 - accuracy: 0.8453
# Epoch 5/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.5259 - accuracy: 0.8480
# Epoch 6/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.5045 - accuracy: 0.8587
# Epoch 7/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.4831 - accuracy: 0.8667
# Epoch 8/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.4624 - accuracy: 0.8720
# Epoch 9/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.4426 - accuracy: 0.8707
# Epoch 10/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.4243 - accuracy: 0.8707
# Epoch 11/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.4074 - accuracy: 0.8733
# Epoch 12/500
# 750/750 [==============================] - 0s 43us/sample - loss: 0.3924 - accuracy: 0.8720
# Epoch 13/500
# 750/750 [==============================] - 0s 41us/sample - loss: 0.3790 - accuracy: 0.8707
# Epoch 14/500
# 750/750 [==============================] - 0s 40us/sample - loss: 0.3675 - accuracy: 0.8747
# Epoch 15/500
# 750/750 [==============================] - 0s 40us/sample - loss: 0.3575 - accuracy: 0.8720
# Epoch 16/500
# 750/750 [==============================] - 0s 40us/sample - loss: 0.3487 - accuracy: 0.8720
# Epoch 17/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.3412 - accuracy: 0.8733
# Epoch 18/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.3347 - accuracy: 0.8747
# Epoch 19/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.3291 - accuracy: 0.8760
# Epoch 20/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.3242 - accuracy: 0.8760
# Epoch 21/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.3198 - accuracy: 0.8760
# Epoch 22/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.3160 - accuracy: 0.8773
# Epoch 23/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.3126 - accuracy: 0.8760
# Epoch 24/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.3093 - accuracy: 0.8760
# Epoch 25/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.3067 - accuracy: 0.8760
# Epoch 26/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.3040 - accuracy: 0.8773
# Epoch 27/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.3018 - accuracy: 0.8760
# Epoch 28/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2999 - accuracy: 0.8760
# Epoch 29/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2986 - accuracy: 0.8773
# Epoch 30/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2966 - accuracy: 0.8773
# Epoch 31/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2953 - accuracy: 0.8773
# Epoch 32/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2938 - accuracy: 0.8773
# Epoch 33/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2929 - accuracy: 0.8787
# Epoch 34/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2916 - accuracy: 0.8800
# Epoch 35/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2906 - accuracy: 0.8800
# Epoch 36/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2896 - accuracy: 0.8800
# Epoch 37/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2887 - accuracy: 0.8787
# Epoch 38/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2880 - accuracy: 0.8800
# Epoch 39/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2873 - accuracy: 0.8840
# Epoch 40/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2861 - accuracy: 0.8853
# Epoch 41/500
# 750/750 [==============================] - 0s 41us/sample - loss: 0.2856 - accuracy: 0.8840
# Epoch 42/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2847 - accuracy: 0.8827
# Epoch 43/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2842 - accuracy: 0.8840
# Epoch 44/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2836 - accuracy: 0.8840
# Epoch 45/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2828 - accuracy: 0.8827
# Epoch 46/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2821 - accuracy: 0.8827
# Epoch 47/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2817 - accuracy: 0.8840
# Epoch 48/500
# 750/750 [==============================] - 0s 41us/sample - loss: 0.2813 - accuracy: 0.8853
# Epoch 49/500
# 750/750 [==============================] - 0s 39us/sample - loss: 0.2805 - accuracy: 0.8867
# Epoch 50/500
# 750/750 [==============================] - 0s 40us/sample - loss: 0.2800 - accuracy: 0.8867
# Epoch 51/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2794 - accuracy: 0.8867
# Epoch 52/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2790 - accuracy: 0.8853
# Epoch 53/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2786 - accuracy: 0.8853
# Epoch 54/500
# 750/750 [==============================] - 0s 39us/sample - loss: 0.2782 - accuracy: 0.8867
# Epoch 55/500
# 750/750 [==============================] - 0s 39us/sample - loss: 0.2776 - accuracy: 0.8853
# Epoch 56/500
# 750/750 [==============================] - 0s 40us/sample - loss: 0.2772 - accuracy: 0.8853
# Epoch 57/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2766 - accuracy: 0.8853
# Epoch 58/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2763 - accuracy: 0.8853
# Epoch 59/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2758 - accuracy: 0.8840
# Epoch 60/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2754 - accuracy: 0.8827
# Epoch 61/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2750 - accuracy: 0.8840
# Epoch 62/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2745 - accuracy: 0.8827
# Epoch 63/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2741 - accuracy: 0.8827
# Epoch 64/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2737 - accuracy: 0.8827
# Epoch 65/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2737 - accuracy: 0.8840
# Epoch 66/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2730 - accuracy: 0.8840
# Epoch 67/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2726 - accuracy: 0.8840
# Epoch 68/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2723 - accuracy: 0.8827
# Epoch 69/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2719 - accuracy: 0.8840
# Epoch 70/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2715 - accuracy: 0.8840
# Epoch 71/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2710 - accuracy: 0.8840
# Epoch 72/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2706 - accuracy: 0.8827
# Epoch 73/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2705 - accuracy: 0.8840
# Epoch 74/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2700 - accuracy: 0.8840
# Epoch 75/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2697 - accuracy: 0.8840
# Epoch 76/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2694 - accuracy: 0.8827
# Epoch 77/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2690 - accuracy: 0.8827
# Epoch 78/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2685 - accuracy: 0.8840
# Epoch 79/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2686 - accuracy: 0.8827
# Epoch 80/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2680 - accuracy: 0.8840
# Epoch 81/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2676 - accuracy: 0.8840
# Epoch 82/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2673 - accuracy: 0.8827
# Epoch 83/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2672 - accuracy: 0.8827
# Epoch 84/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2672 - accuracy: 0.8840
# Epoch 85/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2666 - accuracy: 0.8840
# Epoch 86/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2664 - accuracy: 0.8853
# Epoch 87/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2661 - accuracy: 0.8827
# Epoch 88/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2657 - accuracy: 0.8827
# Epoch 89/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2657 - accuracy: 0.8840
# Epoch 90/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2654 - accuracy: 0.8813
# Epoch 91/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2651 - accuracy: 0.8813
# Epoch 92/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2651 - accuracy: 0.8827
# Epoch 93/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2647 - accuracy: 0.8840
# Epoch 94/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2648 - accuracy: 0.8813
# Epoch 95/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2645 - accuracy: 0.8827
# Epoch 96/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2641 - accuracy: 0.8840
# Epoch 97/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2638 - accuracy: 0.8840
# Epoch 98/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2637 - accuracy: 0.8840
# Epoch 99/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2633 - accuracy: 0.8827
# Epoch 100/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2633 - accuracy: 0.8827
# Epoch 101/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2633 - accuracy: 0.8813
# Epoch 102/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2630 - accuracy: 0.8827
# Epoch 103/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2628 - accuracy: 0.8813
# Epoch 104/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2626 - accuracy: 0.8813
# Epoch 105/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2625 - accuracy: 0.8813
# Epoch 106/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2623 - accuracy: 0.8813
# Epoch 107/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2623 - accuracy: 0.8813
# Epoch 108/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2620 - accuracy: 0.8813
# Epoch 109/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2621 - accuracy: 0.8813
# Epoch 110/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2619 - accuracy: 0.8813
# Epoch 111/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2617 - accuracy: 0.8840
# Epoch 112/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2617 - accuracy: 0.8813
# Epoch 113/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2614 - accuracy: 0.8813
# Epoch 114/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2616 - accuracy: 0.8853
# Epoch 115/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2611 - accuracy: 0.8813
# Epoch 116/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2610 - accuracy: 0.8827
# Epoch 117/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2611 - accuracy: 0.8827
# Epoch 118/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2608 - accuracy: 0.8827
# Epoch 119/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2607 - accuracy: 0.8827
# Epoch 120/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2607 - accuracy: 0.8827
# Epoch 121/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2605 - accuracy: 0.8840
# Epoch 122/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2604 - accuracy: 0.8853
# Epoch 123/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2603 - accuracy: 0.8840
# Epoch 124/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2605 - accuracy: 0.8840
# Epoch 125/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2600 - accuracy: 0.8840
# Epoch 126/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2601 - accuracy: 0.8827
# Epoch 127/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2599 - accuracy: 0.8840
# Epoch 128/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2598 - accuracy: 0.8840
# Epoch 129/500
# 750/750 [==============================] - 0s 40us/sample - loss: 0.2598 - accuracy: 0.8840
# Epoch 130/500
# 750/750 [==============================] - 0s 39us/sample - loss: 0.2596 - accuracy: 0.8840
# Epoch 131/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2595 - accuracy: 0.8840
# Epoch 132/500
# 750/750 [==============================] - 0s 40us/sample - loss: 0.2594 - accuracy: 0.8853
# Epoch 133/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2591 - accuracy: 0.8853
# Epoch 134/500
# 750/750 [==============================] - 0s 40us/sample - loss: 0.2591 - accuracy: 0.8853
# Epoch 135/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2591 - accuracy: 0.8853
# Epoch 136/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2590 - accuracy: 0.8840
# Epoch 137/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2589 - accuracy: 0.8840
# Epoch 138/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2589 - accuracy: 0.8840
# Epoch 139/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2588 - accuracy: 0.8853
# Epoch 140/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2586 - accuracy: 0.8867
# Epoch 141/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2586 - accuracy: 0.8853
# Epoch 142/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2583 - accuracy: 0.8840
# Epoch 143/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2584 - accuracy: 0.8853
# Epoch 144/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2583 - accuracy: 0.8853
# Epoch 145/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2580 - accuracy: 0.8853
# Epoch 146/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2581 - accuracy: 0.8853
# Epoch 147/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2580 - accuracy: 0.8853
# Epoch 148/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2579 - accuracy: 0.8853
# Epoch 149/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2578 - accuracy: 0.8853
# Epoch 150/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2576 - accuracy: 0.8853
# Epoch 151/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2577 - accuracy: 0.8840
# Epoch 152/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2576 - accuracy: 0.8853
# Epoch 153/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2574 - accuracy: 0.8853
# Epoch 154/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2572 - accuracy: 0.8853
# Epoch 155/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2572 - accuracy: 0.8853
# Epoch 156/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2572 - accuracy: 0.8853
# Epoch 157/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2572 - accuracy: 0.8840
# Epoch 158/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2570 - accuracy: 0.8840
# Epoch 159/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2570 - accuracy: 0.8840
# Epoch 160/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2569 - accuracy: 0.8853
# Epoch 161/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2569 - accuracy: 0.8853
# Epoch 162/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2568 - accuracy: 0.8853
# Epoch 163/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2567 - accuracy: 0.8853
# Epoch 164/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2568 - accuracy: 0.8867
# Epoch 165/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2567 - accuracy: 0.8867
# Epoch 166/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2564 - accuracy: 0.8853
# Epoch 167/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2564 - accuracy: 0.8853
# Epoch 168/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2564 - accuracy: 0.8853
# Epoch 169/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2564 - accuracy: 0.8867
# Epoch 170/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2564 - accuracy: 0.8867
# Epoch 171/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2562 - accuracy: 0.8853
# Epoch 172/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2564 - accuracy: 0.8853
# Epoch 173/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2562 - accuracy: 0.8867
# Epoch 174/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2563 - accuracy: 0.8867
# Epoch 175/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2561 - accuracy: 0.8853
# Epoch 176/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2561 - accuracy: 0.8840
# Epoch 177/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2563 - accuracy: 0.8853
# Epoch 178/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2558 - accuracy: 0.8853
# Epoch 179/500
# 750/750 [==============================] - 0s 40us/sample - loss: 0.2559 - accuracy: 0.8867
# Epoch 180/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2558 - accuracy: 0.8853
# Epoch 181/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2560 - accuracy: 0.8880
# Epoch 182/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2556 - accuracy: 0.8867
# Epoch 183/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2557 - accuracy: 0.8867
# Epoch 184/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2556 - accuracy: 0.8853
# Epoch 185/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2556 - accuracy: 0.8853
# Epoch 186/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2559 - accuracy: 0.8867
# Epoch 187/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2556 - accuracy: 0.8867
# Epoch 188/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2554 - accuracy: 0.8867
# Epoch 189/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2554 - accuracy: 0.8880
# Epoch 190/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2553 - accuracy: 0.8880
# Epoch 191/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2553 - accuracy: 0.8880
# Epoch 192/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2552 - accuracy: 0.8880
# Epoch 193/500
# 750/750 [==============================] - 0s 39us/sample - loss: 0.2551 - accuracy: 0.8853
# Epoch 194/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2552 - accuracy: 0.8840
# Epoch 195/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2552 - accuracy: 0.8840
# Epoch 196/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2551 - accuracy: 0.8827
# Epoch 197/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2552 - accuracy: 0.8867
# Epoch 198/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2553 - accuracy: 0.8813
# Epoch 199/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2551 - accuracy: 0.8840
# Epoch 200/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2550 - accuracy: 0.8867
# Epoch 201/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2552 - accuracy: 0.8867
# Epoch 202/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2549 - accuracy: 0.8827
# Epoch 203/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2553 - accuracy: 0.8840
# Epoch 204/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2549 - accuracy: 0.8867
# Epoch 205/500
# 750/750 [==============================] - 0s 41us/sample - loss: 0.2547 - accuracy: 0.8880
# Epoch 206/500
# 750/750 [==============================] - 0s 39us/sample - loss: 0.2548 - accuracy: 0.8880
# Epoch 207/500
# 750/750 [==============================] - 0s 40us/sample - loss: 0.2550 - accuracy: 0.8880
# Epoch 208/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2547 - accuracy: 0.8880
# Epoch 209/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2547 - accuracy: 0.8880
# Epoch 210/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2549 - accuracy: 0.8840
# Epoch 211/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2548 - accuracy: 0.8853
# Epoch 212/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2546 - accuracy: 0.8880
# Epoch 213/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2546 - accuracy: 0.8880
# Epoch 214/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2546 - accuracy: 0.8880
# Epoch 215/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2546 - accuracy: 0.8867
# Epoch 216/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2546 - accuracy: 0.8827
# Epoch 217/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2547 - accuracy: 0.8880
# Epoch 218/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2545 - accuracy: 0.8853
# Epoch 219/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2545 - accuracy: 0.8840
# Epoch 220/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2543 - accuracy: 0.8880
# Epoch 221/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2544 - accuracy: 0.8880
# Epoch 222/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2542 - accuracy: 0.8853
# Epoch 223/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2543 - accuracy: 0.8893
# Epoch 224/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2544 - accuracy: 0.8867
# Epoch 225/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2545 - accuracy: 0.8867
# Epoch 226/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2542 - accuracy: 0.8867
# Epoch 227/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2541 - accuracy: 0.8867
# Epoch 228/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2543 - accuracy: 0.8867
# Epoch 229/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2544 - accuracy: 0.8880
# Epoch 230/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2541 - accuracy: 0.8880
# Epoch 231/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2542 - accuracy: 0.8853
# Epoch 232/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2542 - accuracy: 0.8867
# Epoch 233/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2540 - accuracy: 0.8880
# Epoch 234/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2541 - accuracy: 0.8853
# Epoch 235/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2542 - accuracy: 0.8853
# Epoch 236/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2540 - accuracy: 0.8867
# Epoch 237/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2540 - accuracy: 0.8880
# Epoch 238/500
# 750/750 [==============================] - 0s 47us/sample - loss: 0.2540 - accuracy: 0.8853
# Epoch 239/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2540 - accuracy: 0.8867
# Epoch 240/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2540 - accuracy: 0.8867
# Epoch 241/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2540 - accuracy: 0.8853
# Epoch 242/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2539 - accuracy: 0.8880
# Epoch 243/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2539 - accuracy: 0.8867
# Epoch 244/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2542 - accuracy: 0.8853
# Epoch 245/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2539 - accuracy: 0.8853
# Epoch 246/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2542 - accuracy: 0.8853
# Epoch 247/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2539 - accuracy: 0.8853
# Epoch 248/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2538 - accuracy: 0.8853
# Epoch 249/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2539 - accuracy: 0.8853
# Epoch 250/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2538 - accuracy: 0.8853
# Epoch 251/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2538 - accuracy: 0.8867
# Epoch 252/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2541 - accuracy: 0.8827
# Epoch 253/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2538 - accuracy: 0.8853
# Epoch 254/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2539 - accuracy: 0.8867
# Epoch 255/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2538 - accuracy: 0.8867
# Epoch 256/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2537 - accuracy: 0.8853
# Epoch 257/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2539 - accuracy: 0.8867
# Epoch 258/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2537 - accuracy: 0.8867
# Epoch 259/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2536 - accuracy: 0.8853
# Epoch 260/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2536 - accuracy: 0.8867
# Epoch 261/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2537 - accuracy: 0.8867
# Epoch 262/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2537 - accuracy: 0.8827
# Epoch 263/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2535 - accuracy: 0.8853
# Epoch 264/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2534 - accuracy: 0.8840
# Epoch 265/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2536 - accuracy: 0.8840
# Epoch 266/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2537 - accuracy: 0.8840
# Epoch 267/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2534 - accuracy: 0.8827
# Epoch 268/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2538 - accuracy: 0.8827
# Epoch 269/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2532 - accuracy: 0.8827
# Epoch 270/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2535 - accuracy: 0.8853
# Epoch 271/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2533 - accuracy: 0.8867
# Epoch 272/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2534 - accuracy: 0.8853
# Epoch 273/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2534 - accuracy: 0.8840
# Epoch 274/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2533 - accuracy: 0.8853
# Epoch 275/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2533 - accuracy: 0.8867
# Epoch 276/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2533 - accuracy: 0.8840
# Epoch 277/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2533 - accuracy: 0.8840
# Epoch 278/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2532 - accuracy: 0.8853
# Epoch 279/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2534 - accuracy: 0.8840
# Epoch 280/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2533 - accuracy: 0.8840
# Epoch 281/500
# 750/750 [==============================] - 0s 40us/sample - loss: 0.2533 - accuracy: 0.8813
# Epoch 282/500
# 750/750 [==============================] - 0s 39us/sample - loss: 0.2531 - accuracy: 0.8840
# Epoch 283/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2533 - accuracy: 0.8827
# Epoch 284/500
# 750/750 [==============================] - 0s 39us/sample - loss: 0.2532 - accuracy: 0.8840
# Epoch 285/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2535 - accuracy: 0.8867
# Epoch 286/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2532 - accuracy: 0.8827
# Epoch 287/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2531 - accuracy: 0.8813
# Epoch 288/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2532 - accuracy: 0.8853
# Epoch 289/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2530 - accuracy: 0.8827
# Epoch 290/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2531 - accuracy: 0.8827
# Epoch 291/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2531 - accuracy: 0.8840
# Epoch 292/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2531 - accuracy: 0.8827
# Epoch 293/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2529 - accuracy: 0.8827
# Epoch 294/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2531 - accuracy: 0.8840
# Epoch 295/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2530 - accuracy: 0.8840
# Epoch 296/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2531 - accuracy: 0.8840
# Epoch 297/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2530 - accuracy: 0.8840
# Epoch 298/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2529 - accuracy: 0.8840
# Epoch 299/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2529 - accuracy: 0.8853
# Epoch 300/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2529 - accuracy: 0.8827
# Epoch 301/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2529 - accuracy: 0.8827
# Epoch 302/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2532 - accuracy: 0.8827
# Epoch 303/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2530 - accuracy: 0.8840
# Epoch 304/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2534 - accuracy: 0.8800
# Epoch 305/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2529 - accuracy: 0.8800
# Epoch 306/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2531 - accuracy: 0.8813
# Epoch 307/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2530 - accuracy: 0.8840
# Epoch 308/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2530 - accuracy: 0.8800
# Epoch 309/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2529 - accuracy: 0.8813
# Epoch 310/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2528 - accuracy: 0.8867
# Epoch 311/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2527 - accuracy: 0.8827
# Epoch 312/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2531 - accuracy: 0.8813
# Epoch 313/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2528 - accuracy: 0.8840
# Epoch 314/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2532 - accuracy: 0.8813
# Epoch 315/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2525 - accuracy: 0.8813
# Epoch 316/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2525 - accuracy: 0.8813
# Epoch 317/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2526 - accuracy: 0.8840
# Epoch 318/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2528 - accuracy: 0.8813
# Epoch 319/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2527 - accuracy: 0.8813
# Epoch 320/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2527 - accuracy: 0.8813
# Epoch 321/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2534 - accuracy: 0.8840
# Epoch 322/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2533 - accuracy: 0.8840
# Epoch 323/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2525 - accuracy: 0.8827
# Epoch 324/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2525 - accuracy: 0.8813
# Epoch 325/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2527 - accuracy: 0.8840
# Epoch 326/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2531 - accuracy: 0.8840
# Epoch 327/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2527 - accuracy: 0.8813
# Epoch 328/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2526 - accuracy: 0.8827
# Epoch 329/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2526 - accuracy: 0.8840
# Epoch 330/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2527 - accuracy: 0.8813
# Epoch 331/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2525 - accuracy: 0.8827
# Epoch 332/500
# 750/750 [==============================] - 0s 39us/sample - loss: 0.2524 - accuracy: 0.8813
# Epoch 333/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2524 - accuracy: 0.8813
# Epoch 334/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2526 - accuracy: 0.8827
# Epoch 335/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2525 - accuracy: 0.8827
# Epoch 336/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2527 - accuracy: 0.8800
# Epoch 337/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2524 - accuracy: 0.8800
# Epoch 338/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2525 - accuracy: 0.8827
# Epoch 339/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2524 - accuracy: 0.8813
# Epoch 340/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2524 - accuracy: 0.8800
# Epoch 341/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2524 - accuracy: 0.8800
# Epoch 342/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2524 - accuracy: 0.8813
# Epoch 343/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2524 - accuracy: 0.8800
# Epoch 344/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2525 - accuracy: 0.8827
# Epoch 345/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2526 - accuracy: 0.8813
# Epoch 346/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2523 - accuracy: 0.8800
# Epoch 347/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 348/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2527 - accuracy: 0.8813
# Epoch 349/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2525 - accuracy: 0.8800
# Epoch 350/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2524 - accuracy: 0.8827
# Epoch 351/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2524 - accuracy: 0.8813
# Epoch 352/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 353/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 354/500
# 750/750 [==============================] - 0s 39us/sample - loss: 0.2524 - accuracy: 0.8800
# Epoch 355/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2523 - accuracy: 0.8827
# Epoch 356/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2527 - accuracy: 0.8827
# Epoch 357/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2525 - accuracy: 0.8800
# Epoch 358/500
# 750/750 [==============================] - 0s 43us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 359/500
# 750/750 [==============================] - 0s 41us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 360/500
# 750/750 [==============================] - 0s 48us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 361/500
# 750/750 [==============================] - 0s 43us/sample - loss: 0.2522 - accuracy: 0.8827
# Epoch 362/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2522 - accuracy: 0.8813
# Epoch 363/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2525 - accuracy: 0.8800
# Epoch 364/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2525 - accuracy: 0.8827
# Epoch 365/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2522 - accuracy: 0.8813
# Epoch 366/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2523 - accuracy: 0.8840
# Epoch 367/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2526 - accuracy: 0.8800
# Epoch 368/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2524 - accuracy: 0.8813
# Epoch 369/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2523 - accuracy: 0.8800
# Epoch 370/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2522 - accuracy: 0.8827
# Epoch 371/500
# 750/750 [==============================] - 0s 29us/sample - loss: 0.2524 - accuracy: 0.8813
# Epoch 372/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2532 - accuracy: 0.8813
# Epoch 373/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2525 - accuracy: 0.8827
# Epoch 374/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2522 - accuracy: 0.8813
# Epoch 375/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2521 - accuracy: 0.8813
# Epoch 376/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2525 - accuracy: 0.8800
# Epoch 377/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2522 - accuracy: 0.8813
# Epoch 378/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2521 - accuracy: 0.8813
# Epoch 379/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2521 - accuracy: 0.8813
# Epoch 380/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2523 - accuracy: 0.8827
# Epoch 381/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 382/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 383/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2522 - accuracy: 0.8800
# Epoch 384/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2522 - accuracy: 0.8813
# Epoch 385/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2522 - accuracy: 0.8813
# Epoch 386/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2522 - accuracy: 0.8813
# Epoch 387/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 388/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2522 - accuracy: 0.8813
# Epoch 389/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2521 - accuracy: 0.8813
# Epoch 390/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 391/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2525 - accuracy: 0.8853
# Epoch 392/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2522 - accuracy: 0.8827
# Epoch 393/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 394/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2520 - accuracy: 0.8800
# Epoch 395/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2525 - accuracy: 0.8827
# Epoch 396/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2521 - accuracy: 0.8827
# Epoch 397/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2521 - accuracy: 0.8827
# Epoch 398/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2523 - accuracy: 0.8800
# Epoch 399/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2522 - accuracy: 0.8813
# Epoch 400/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2522 - accuracy: 0.8800
# Epoch 401/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2525 - accuracy: 0.8813
# Epoch 402/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2523 - accuracy: 0.8827
# Epoch 403/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2522 - accuracy: 0.8827
# Epoch 404/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2522 - accuracy: 0.8813
# Epoch 405/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2524 - accuracy: 0.8813
# Epoch 406/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 407/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2525 - accuracy: 0.8827
# Epoch 408/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2520 - accuracy: 0.8800
# Epoch 409/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2522 - accuracy: 0.8840
# Epoch 410/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2521 - accuracy: 0.8813
# Epoch 411/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2520 - accuracy: 0.8813
# Epoch 412/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2521 - accuracy: 0.8813
# Epoch 413/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2521 - accuracy: 0.8813
# Epoch 414/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2523 - accuracy: 0.8813
# Epoch 415/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2522 - accuracy: 0.8813
# Epoch 416/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2520 - accuracy: 0.8813
# Epoch 417/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2521 - accuracy: 0.8800
# Epoch 418/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2521 - accuracy: 0.8800
# Epoch 419/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2521 - accuracy: 0.8813
# Epoch 420/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2520 - accuracy: 0.8813
# Epoch 421/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2520 - accuracy: 0.8813
# Epoch 422/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2523 - accuracy: 0.8827
# Epoch 423/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2524 - accuracy: 0.8800
# Epoch 424/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2523 - accuracy: 0.8800
# Epoch 425/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2526 - accuracy: 0.8787
# Epoch 426/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2518 - accuracy: 0.8813
# Epoch 427/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2521 - accuracy: 0.8827
# Epoch 428/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2520 - accuracy: 0.8827
# Epoch 429/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2526 - accuracy: 0.8813
# Epoch 430/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2519 - accuracy: 0.8813
# Epoch 431/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2520 - accuracy: 0.8813
# Epoch 432/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2520 - accuracy: 0.8827
# Epoch 433/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2520 - accuracy: 0.8813
# Epoch 434/500
# 750/750 [==============================] - 0s 39us/sample - loss: 0.2520 - accuracy: 0.8813
# Epoch 435/500
# 750/750 [==============================] - 0s 39us/sample - loss: 0.2521 - accuracy: 0.8813
# Epoch 436/500
# 750/750 [==============================] - 0s 43us/sample - loss: 0.2520 - accuracy: 0.8800
# Epoch 437/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2521 - accuracy: 0.8840
# Epoch 438/500
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2520 - accuracy: 0.8827
# Epoch 439/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2520 - accuracy: 0.8827
# Epoch 440/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2520 - accuracy: 0.8813
# Epoch 441/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2522 - accuracy: 0.8813
# Epoch 442/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2520 - accuracy: 0.8813
# Epoch 443/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2519 - accuracy: 0.8800
# Epoch 444/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2523 - accuracy: 0.8827
# Epoch 445/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2521 - accuracy: 0.8827
# Epoch 446/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2520 - accuracy: 0.8840
# Epoch 447/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2521 - accuracy: 0.8827
# Epoch 448/500
# 750/750 [==============================] - 0s 32us/sample - loss: 0.2520 - accuracy: 0.8813
# Epoch 449/500
# 750/750 [==============================] - 0s 31us/sample - loss: 0.2519 - accuracy: 0.8813
# Epoch 450/500
# 750/750 [==============================] - 0s 33us/sample - loss: 0.2520 - accuracy: 0.8813
# Epoch 451/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2521 - accuracy: 0.8813
# Epoch 452/500
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2520 - accuracy: 0.8800
# Epoch 453/500
# 750/750 [==============================] - 0s 35us/sample - loss: 0.2519 - accuracy: 0.8827
# Epoch 454/500
# ...
# Epoch 385/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0861 - accuracy: 0.9653
# Epoch 386/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0910 - accuracy: 0.9680
# Epoch 387/500
# 750/750 [==============================] - 0s 63us/sample - loss: 0.0760 - accuracy: 0.9733
# Epoch 388/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0911 - accuracy: 0.9667
# Epoch 389/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0832 - accuracy: 0.9693
# Epoch 390/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0760 - accuracy: 0.9733
# Epoch 391/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0718 - accuracy: 0.9720
# Epoch 392/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0756 - accuracy: 0.9707
# Epoch 393/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0776 - accuracy: 0.9680
# Epoch 394/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0772 - accuracy: 0.9707
# Epoch 395/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0801 - accuracy: 0.9760
# Epoch 396/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0762 - accuracy: 0.9760
# Epoch 397/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0810 - accuracy: 0.9693
# Epoch 398/500
# 750/750 [==============================] - 0s 66us/sample - loss: 0.0772 - accuracy: 0.9720
# Epoch 399/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0762 - accuracy: 0.9747
# Epoch 400/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0819 - accuracy: 0.9667
# Epoch 401/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0722 - accuracy: 0.9773
# Epoch 402/500
# 750/750 [==============================] - 0s 60us/sample - loss: 0.0685 - accuracy: 0.9760
# Epoch 403/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0743 - accuracy: 0.9720
# Epoch 404/500
# 750/750 [==============================] - 0s 66us/sample - loss: 0.0700 - accuracy: 0.9760
# Epoch 405/500
# 750/750 [==============================] - 0s 78us/sample - loss: 0.0765 - accuracy: 0.9720
# Epoch 406/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0721 - accuracy: 0.9747
# Epoch 407/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0729 - accuracy: 0.9693
# Epoch 408/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0693 - accuracy: 0.9773
# Epoch 409/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0712 - accuracy: 0.9760
# Epoch 410/500
# 750/750 [==============================] - 0s 59us/sample - loss: 0.0694 - accuracy: 0.9760
# Epoch 411/500
# 750/750 [==============================] - 0s 59us/sample - loss: 0.0711 - accuracy: 0.9747
# Epoch 412/500
# 750/750 [==============================] - 0s 69us/sample - loss: 0.0771 - accuracy: 0.9680
# Epoch 413/500
# 750/750 [==============================] - 0s 68us/sample - loss: 0.0733 - accuracy: 0.9760
# Epoch 414/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0726 - accuracy: 0.9693
# Epoch 415/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0729 - accuracy: 0.9760
# Epoch 416/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0707 - accuracy: 0.9707
# Epoch 417/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0741 - accuracy: 0.9733
# Epoch 418/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0667 - accuracy: 0.9800
# Epoch 419/500
# 750/750 [==============================] - 0s 78us/sample - loss: 0.0818 - accuracy: 0.9693
# Epoch 420/500
# 750/750 [==============================] - 0s 81us/sample - loss: 0.0954 - accuracy: 0.9693
# Epoch 421/500
# 750/750 [==============================] - 0s 81us/sample - loss: 0.0897 - accuracy: 0.9720
# Epoch 422/500
# 750/750 [==============================] - 0s 69us/sample - loss: 0.0930 - accuracy: 0.9680
# Epoch 423/500
# 750/750 [==============================] - 0s 60us/sample - loss: 0.0933 - accuracy: 0.9720
# Epoch 424/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0723 - accuracy: 0.9773
# Epoch 425/500
# 750/750 [==============================] - 0s 66us/sample - loss: 0.0780 - accuracy: 0.9680
# Epoch 426/500
# 750/750 [==============================] - 0s 68us/sample - loss: 0.0861 - accuracy: 0.9653
# Epoch 427/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0758 - accuracy: 0.9707
# Epoch 428/500
# 750/750 [==============================] - 0s 69us/sample - loss: 0.0713 - accuracy: 0.9720
# Epoch 429/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0721 - accuracy: 0.9720
# Epoch 430/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0681 - accuracy: 0.9773
# Epoch 431/500
# 750/750 [==============================] - 0s 63us/sample - loss: 0.0681 - accuracy: 0.9773
# Epoch 432/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0799 - accuracy: 0.9693
# Epoch 433/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0803 - accuracy: 0.9653
# Epoch 434/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0735 - accuracy: 0.9720
# Epoch 435/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0722 - accuracy: 0.9733
# Epoch 436/500
# 750/750 [==============================] - 0s 66us/sample - loss: 0.0649 - accuracy: 0.9747
# Epoch 437/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0688 - accuracy: 0.9733
# Epoch 438/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0701 - accuracy: 0.9707
# Epoch 439/500
# 750/750 [==============================] - 0s 72us/sample - loss: 0.0670 - accuracy: 0.9760
# Epoch 440/500
# 750/750 [==============================] - 0s 73us/sample - loss: 0.0661 - accuracy: 0.9747
# Epoch 441/500
# 750/750 [==============================] - 0s 69us/sample - loss: 0.0680 - accuracy: 0.9760
# Epoch 442/500
# 750/750 [==============================] - 0s 69us/sample - loss: 0.0731 - accuracy: 0.9733
# Epoch 443/500
# 750/750 [==============================] - 0s 62us/sample - loss: 0.0754 - accuracy: 0.9733
# Epoch 444/500
# 750/750 [==============================] - 0s 63us/sample - loss: 0.0700 - accuracy: 0.9760
# Epoch 445/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0762 - accuracy: 0.9720
# Epoch 446/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0661 - accuracy: 0.9747
# Epoch 447/500
# 750/750 [==============================] - 0s 70us/sample - loss: 0.0685 - accuracy: 0.9773
# Epoch 448/500
# 750/750 [==============================] - 0s 68us/sample - loss: 0.0660 - accuracy: 0.9773
# Epoch 449/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0675 - accuracy: 0.9773
# Epoch 450/500
# 750/750 [==============================] - 0s 60us/sample - loss: 0.0668 - accuracy: 0.9760
# Epoch 451/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0646 - accuracy: 0.9840
# Epoch 452/500
# 750/750 [==============================] - 0s 69us/sample - loss: 0.0648 - accuracy: 0.9787
# Epoch 453/500
# 750/750 [==============================] - 0s 68us/sample - loss: 0.0658 - accuracy: 0.9747
# Epoch 454/500
# 750/750 [==============================] - 0s 62us/sample - loss: 0.0780 - accuracy: 0.9707
# Epoch 455/500
# 750/750 [==============================] - 0s 69us/sample - loss: 0.0738 - accuracy: 0.9693
# Epoch 456/500
# 750/750 [==============================] - 0s 66us/sample - loss: 0.0713 - accuracy: 0.9760
# Epoch 457/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0692 - accuracy: 0.9733
# Epoch 458/500
# 750/750 [==============================] - 0s 72us/sample - loss: 0.0676 - accuracy: 0.9747
# Epoch 459/500
# 750/750 [==============================] - 0s 81us/sample - loss: 0.0673 - accuracy: 0.9773
# Epoch 460/500
# 750/750 [==============================] - 0s 81us/sample - loss: 0.0826 - accuracy: 0.9653
# Epoch 461/500
# 750/750 [==============================] - 0s 77us/sample - loss: 0.0782 - accuracy: 0.9680
# Epoch 462/500
# 750/750 [==============================] - 0s 69us/sample - loss: 0.0835 - accuracy: 0.9693
# Epoch 463/500
# 750/750 [==============================] - 0s 68us/sample - loss: 0.0755 - accuracy: 0.9693
# Epoch 464/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0689 - accuracy: 0.9747
# Epoch 465/500
# 750/750 [==============================] - 0s 63us/sample - loss: 0.0697 - accuracy: 0.9720
# Epoch 466/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0650 - accuracy: 0.9787
# Epoch 467/500
# 750/750 [==============================] - 0s 66us/sample - loss: 0.0644 - accuracy: 0.9760
# Epoch 468/500
# 750/750 [==============================] - 0s 60us/sample - loss: 0.0659 - accuracy: 0.9787
# Epoch 469/500
# 750/750 [==============================] - 0s 68us/sample - loss: 0.0637 - accuracy: 0.9760
# Epoch 470/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0676 - accuracy: 0.9760
# Epoch 471/500
# 750/750 [==============================] - 0s 70us/sample - loss: 0.0650 - accuracy: 0.9747
# Epoch 472/500
# 750/750 [==============================] - 0s 63us/sample - loss: 0.0651 - accuracy: 0.9787
# Epoch 473/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0645 - accuracy: 0.9760
# Epoch 474/500
# 750/750 [==============================] - 0s 66us/sample - loss: 0.0626 - accuracy: 0.9760
# Epoch 475/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0657 - accuracy: 0.9787
# Epoch 476/500
# 750/750 [==============================] - 0s 66us/sample - loss: 0.0749 - accuracy: 0.9720
# Epoch 477/500
# 750/750 [==============================] - 0s 60us/sample - loss: 0.0746 - accuracy: 0.9760
# Epoch 478/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0716 - accuracy: 0.9720
# Epoch 479/500
# 750/750 [==============================] - 0s 66us/sample - loss: 0.0666 - accuracy: 0.9747
# Epoch 480/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0629 - accuracy: 0.9773
# Epoch 481/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0605 - accuracy: 0.9800
# Epoch 482/500
# 750/750 [==============================] - 0s 62us/sample - loss: 0.0564 - accuracy: 0.9827
# Epoch 483/500
# 750/750 [==============================] - 0s 62us/sample - loss: 0.0594 - accuracy: 0.9773
# Epoch 484/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0680 - accuracy: 0.9747
# Epoch 485/500
# 750/750 [==============================] - 0s 60us/sample - loss: 0.0620 - accuracy: 0.9773
# Epoch 486/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0635 - accuracy: 0.9787
# Epoch 487/500
# 750/750 [==============================] - 0s 66us/sample - loss: 0.0652 - accuracy: 0.9720
# Epoch 488/500
# 750/750 [==============================] - 0s 65us/sample - loss: 0.0624 - accuracy: 0.9733
# Epoch 489/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0636 - accuracy: 0.9787
# Epoch 490/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0610 - accuracy: 0.9800
# Epoch 491/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0654 - accuracy: 0.9773
# Epoch 492/500
# 750/750 [==============================] - 0s 62us/sample - loss: 0.0620 - accuracy: 0.9800
# Epoch 493/500
# 750/750 [==============================] - 0s 72us/sample - loss: 0.0630 - accuracy: 0.9827
# Epoch 494/500
# 750/750 [==============================] - 0s 69us/sample - loss: 0.0578 - accuracy: 0.9773
# Epoch 495/500
# 750/750 [==============================] - 0s 63us/sample - loss: 0.0680 - accuracy: 0.9720
# Epoch 496/500
# 750/750 [==============================] - 0s 61us/sample - loss: 0.0609 - accuracy: 0.9747
# Epoch 497/500
# 750/750 [==============================] - 0s 64us/sample - loss: 0.0601 - accuracy: 0.9773
# Epoch 498/500
# 750/750 [==============================] - 0s 81us/sample - loss: 0.0638 - accuracy: 0.9813
# Epoch 499/500
# 750/750 [==============================] - 0s 77us/sample - loss: 0.0715 - accuracy: 0.9720
# Epoch 500/500
# 750/750 [==============================] - 0s 69us/sample - loss: 0.0757 - accuracy: 0.9707
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-b339c38abb98> in <module>
#     212
#     213 if __name__ == '__main__':
# --> 214     main()
#
# <ipython-input-15-b339c38abb98> in main()
#     208     dropout_influence(X_train, y_train)
#     209     # 正则化的影响
# --> 210     regularizers_influence(X_train, y_train)
#     211
#     212
#
# <ipython-input-15-b339c38abb98> in regularizers_influence(X_train, y_train)
#     185         file_name = "正则化网络权值_" + str(_lambda)
#     186         # 绘制网络权值范围图
# --> 187         plot_weights_matrix(model, layer_index, plot_title, file_name, output_dir=OUTPUT_DIR + '/regularizers')
#     188         # 绘制不同正则化系数的决策边界线
#     189         # 可视化的 x 坐标范围为[-2, 3]
#
# <ipython-input-15-b339c38abb98> in plot_weights_matrix(model, layer_index, plot_name, file_name, output_dir)
#     170     ax.set_zlabel('权值', fontsize=16, rotation=90, fontproperties='SimHei')
#     171     # 保存矩阵范围图
# --> 172     plt.savefig(output_dir + "/" + file_name + ".svg")
#     173     plt.close(fig)
#     174
#
# D:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# D:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# D:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2091                     orientation=orientation,
#    2092                     bbox_inches_restore=_bbox_inches_restore,
# -> 2093                     **kwargs)
#    2094             finally:
#    2095                 if bbox_inches and restore_bbox:
#
# D:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\matplotlib\backends\backend_svg.py in print_svg(self, filename, *args, **kwargs)
#    1182
#    1183     def print_svg(self, filename, *args, **kwargs):
# -> 1184         with cbook.open_file_cm(filename, "w", encoding="utf-8") as fh:
#    1185
#    1186             filename = getattr(fh, 'name', '')
#
# D:\ProgramData\Anaconda3\envs\tf2\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# D:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# D:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_dir/regularizers/正则化网络权值_1e-05.svg'
